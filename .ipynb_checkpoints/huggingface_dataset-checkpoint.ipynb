# %% [markdown]
# # Run CleanVision on a Hugging Face dataset

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cleanlab/cleanvision/blob/main/docs/source/tutorials/huggingface_dataset.ipynb)

# %%
# !pip install -U pip
# !pip install "cleanvision[huggingface] @ git+https://github.com/cleanlab/cleanvision.git"
# Out:
# Requirement already satisfied: pip in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (23.3.1)
# Collecting cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git
#   Cloning https://github.com/cleanlab/cleanvision.git to /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-xwtdi4y8/cleanvision_6d3f28641faa4f23957e46506fc19303
#   Running command git clone --filter=blob:none --quiet https://github.com/cleanlab/cleanvision.git /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-install-xwtdi4y8/cleanvision_6d3f28641faa4f23957e46506fc19303
#   Resolved https://github.com/cleanlab/cleanvision.git to commit 2814ed82daddb41692c3b2b06d7296ef14c243c5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Pillow>=9.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (10.0.0)
# Requirement already satisfied: numpy>=1.20.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.23.5)
# Requirement already satisfied: pandas>=1.1.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2.0.1)
# Requirement already satisfied: tabulate>=0.8.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (0.8.10)
# Requirement already satisfied: imagehash>=4.2.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (4.3.1)
# Requirement already satisfied: tqdm>=4.53.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (4.65.0)
# Requirement already satisfied: matplotlib>=3.4 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (3.8.0)
# Requirement already satisfied: fsspec>=2023.1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2023.6.0)
# Requirement already satisfied: datasets>=2.7.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2.14.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (11.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (0.3.6)
# Requirement already satisfied: requests>=2.19.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2.31.0)
# Requirement already satisfied: xxhash in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (3.2.0)
# Requirement already satisfied: multiprocess in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (0.70.14)
# Requirement already satisfied: aiohttp in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (0.18.0)
# Requirement already satisfied: packaging in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (6.0)
# Requirement already satisfied: PyWavelets in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from imagehash>=4.2.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.4.1)
# Requirement already satisfied: scipy in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from imagehash>=4.2.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.4->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.4->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.4->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.4->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.4->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from matplotlib>=3.4->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.5->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from pandas>=1.1.5->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2023.3)
# Requirement already satisfied: six in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from cycler>=0.10->matplotlib>=3.4->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from aiohttp->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.3.1)
# Requirement already satisfied: filelock in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/michielbontenbal/anaconda3/lib/python3.10/site-packages (from requests>=2.19.0->datasets>=2.7.0->cleanvision[huggingface]@ git+https://github.com/cleanlab/cleanvision.git) (2022.12.7)
# Building wheels for collected packages: cleanvision
#   Building wheel for cleanvision (pyproject.toml) ... done
#   Created wheel for cleanvision: filename=cleanvision-0.3.5-py3-none-any.whl size=55593 sha256=5e6d99df4f334fa87b57642fa3cc87b9765b9bd12c0b32d3707811461f4c9504
#   Stored in directory: /private/var/folders/cj/qtbz9fvd3svc0x28yv2756mh0000gn/T/pip-ephem-wheel-cache-2m_9d4hb/wheels/62/b5/93/1e928b2ed86f4723a6f82d41084fe213c8e28e744104d35a0f
# Successfully built cleanvision
# Installing collected packages: cleanvision
#   Attempting uninstall: cleanvision
#     Found existing installation: cleanvision 0.3.4
#     Uninstalling cleanvision-0.3.4:
#       Successfully uninstalled cleanvision-0.3.4
# Successfully installed cleanvision-0.3.5

# %% [markdown]
# **After you install these packages, you may need to restart your notebook runtime before running the rest of this notebook.**

# %%
from datasets import load_dataset
from cleanvision import Imagelab

# %% [markdown]
# ### 1. Download dataset
#
# [cats_vs_dogs](https://huggingface.co/datasets/cats_vs_dogs) is a subset of Assira dataset which contains millions of images of pets classified into cats and dogs.
#
# Please note though this a classification dataset, CleanVision can be used to audit images from any type of dataset (including supervised or unsupervised learning).
#
# Load train split of the dataset.

# %%
dataset = load_dataset("cats_vs_dogs", split="train")

# %% [markdown]
# See more information on the dataset like features and number of examples

# %%
dataset
# Out:
# Dataset({
#     features: ['image', 'labels'],
#     num_rows: 23410
# })

# %% [markdown]
# `dataset.features` is a `dict[column_name, column_type]` that contains information about the different columns in the dataset and the type of each column. Use `dataset.features` to find the key that contains the Image feature.

# %%
dataset.features
# Out:
# {'image': Image(decode=True, id=None),
#  'labels': ClassLabel(names=['cat', 'dog'], id=None)}

# %% [markdown]
# ### 2. View sample images in the dataset

# %% [markdown]
# Initialize Imagelab

# %%
imagelab = Imagelab(hf_dataset=dataset, image_key="image")

# %%
imagelab.visualize()
# Out:
# Sample images from the dataset

# %% [markdown]
# ### 3. Run CleanVision

# %%
imagelab.find_issues()
# Out:
# Checking for dark, light, odd_aspect_ratio, low_information, exact_duplicates, near_duplicates, blurry, grayscale, odd_size images ...
#   0%|          | 0/23410 [00:00<?, ?it/s]
#   0%|          | 0/23410 [00:00<?, ?it/s]

# %% [markdown]
# ### 4. View Results
# Get a report of all the issues found

# %%
imagelab.report()

# %% [markdown]
# View more information about each image, such as what types of issues it exhibits and its quality score with respect to each type of issue.

# %%
imagelab.issues

# %% [markdown]
# Get indices of all **blurry** images in the dataset sorted by their blurry score.

# %%
indices = imagelab.issues.query('is_blurry_issue').sort_values(by='blurry_score').index.tolist()

# %% [markdown]
# View the 8th blurriest image in the dataset

# %%
dataset[indices[8]]['image']

# %% [markdown]
# View global information about each issue, such as how many images in the dataset suffer from this issue.

# %%
imagelab.issue_summary

# %% [markdown]
# **For more detailed guide on how to use CleanVision, check the [tutorial notebook](https://github.com/cleanlab/cleanvision/blob/main/docs/source/tutorials/tutorial.ipynb).**
